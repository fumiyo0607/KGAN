# %%
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
import os
import numpy as np

# %%
target = 'test'
# target = 'train'

data_path = './data/last-fm/'
row_data_path = './row_data/LFM-1b/'

# %% [markdown]
# #### *.txt の読み込み

# %%
all_data = defaultdict(list)
f = open( data_path + '{}.txt'.format(target))
line = f.readline()

while line :

    data = line.strip()
    data_list = data.split()

    user = data_list[0]
    items = data_list[1:]
    all_data[user] = items
    
    line = f.readline()
    
f.close()

# %% [markdown]
# #### txt data をDataFrameに整形

# %%
user_list = []
item_list = []

for user, items in all_data.items():
    
    for item in items:
        user_list.append(user)
        item_list.append(item)

# %%
data_df = pd.DataFrame(
    data = {
        'user_id' : user_list,
        'item_id' : item_list
    },
    columns=['user_id', 'item_id']
)

# %%
data_df.head()
# Out:
#   user_id item_id
# 0       0      72
# 1       0      73
# 2       0      74
# 3       0      75
# 4       0      76

# %% [markdown]
# #### item_list.txt の読み込み

# %%
item_df = pd.read_csv( data_path + 'item_list.txt', sep=' ')
item_df.head(5)
# Out:
#      org_id  remap_id freebase_id
# 0    152949         0   m.0f7jpbw
# 1    154518         1   m.0v1_6dj
# 2     64981         2    m.0mbpxv
# 3  11325966         3    m.0lh896
# 4    186771         4   m.0dykj_8

# %% [markdown]
# #### item_id と org_id (last-fm) を結合

# %%
data_df['item_id'] = data_df['item_id'].astype(np.int64)

# %%
df = pd.merge(
                    data_df, item_df, 
                    left_on='item_id', 
                    right_on='remap_id', 
                    how='left'
             ).drop(columns='remap_id')

# %%
df.head(10)
# Out:
#   user_id  item_id  org_id freebase_id
# 0       0       72   16782    m.0qh8tx
# 1       0       73   16781    m.0qh8v3
# 2       0       74   16780    m.0qh8vb
# 3       0       75   16779    m.0qh8vk
# 4       0       76   16778    m.0w2yfq
# 5       0       77   16777    m.0qh8v_
# 6       0     9725   16776    m.0qh8w6
# 7       0     9726   16775   m.0dvhv4c
# 8       0     9727   16774    m.0qh8wn
# 9       0     9762   16773    m.0qh8ww

# %% [markdown]
# #### last fm data の読み込み

# %%
last_fm_stack_df = pd.read_csv(
    row_data_path + 'LFM-1b_tracks.txt', 
    sep='\t', 
    header=None, 
    names=('org_id', 'track_name', 'artist_id')
)

# %%
last_fm_stack_df.head(5)
# Out:
#    org_id                    track_name  artist_id
# 0       1              A Matter of Time          3
# 1       2                     Hangar 18          1
# 2       3              Up the Downstair          4
# 3       4  Mr. Carter (Featuring Jay-Z)          2
# 4       5                      Mixtaped          5

# %%
last_fm_artists_df = pd.read_csv(
    row_data_path + 'LFM-1b_artists.txt', 
    sep='\t',
    header=None, 
    names=('artist_id', 'artist_name')
)

# %%
last_fm_artists_df.head(5)
# Out:
#    artist_id     artist_name
# 0          1        Megadeth
# 1          2       Lil Wayne
# 2          3    Foo Fighters
# 3          4  Porcupine Tree
# 4          5          No-Man

# %%
last_fm_df = pd.merge(
    last_fm_stack_df, last_fm_artists_df,
    on='artist_id',
    how='left'
)

# %%
last_fm_df.head(5)
# Out:
#    org_id                    track_name  artist_id     artist_name
# 0       1              A Matter of Time          3    Foo Fighters
# 1       2                     Hangar 18          1        Megadeth
# 2       3              Up the Downstair          4  Porcupine Tree
# 3       4  Mr. Carter (Featuring Jay-Z)          2       Lil Wayne
# 4       5                      Mixtaped          5          No-Man

# %% [markdown]
# #### モデルの学習用データとLast-FMのデータを結合

# %%
all_data_df = pd.merge(
    df, last_fm_df,
    on='org_id',
    how='left'
)

# %%
all_data_df = all_data_df.drop_duplicates()
all_data_df.head(10)
# Out:
#   user_id  item_id  org_id freebase_id                             track_name  \
# 0       0       72   16782    m.0qh8tx                       Needles and Pins
# 1       0       73   16781    m.0qh8v3                                Minerva
# 2       0       74   16780    m.0qh8vb                 Good Morning Beautiful
# 3       0       75   16779    m.0qh8vk                              Deathblow
# 4       0       76   16778    m.0w2yfq              When Girls Telephone Boys
# 5       0       77   16777    m.0qh8v_                             Battle-Axe
# 6       0     9725   16776    m.0qh8w6                              Lucky You
# 7       0     9726   16775   m.0dvhv4c                            Bloody Cape
# 8       0     9727   16774    m.0qh8wn  Anniversary of an Uninteresting Event
# 9       0     9762   16773    m.0qh8ww                                  Moana
#
#    artist_id artist_name
# 0      362.0    Deftones
# 1      362.0    Deftones
# 2      362.0    Deftones
# 3      362.0    Deftones
# 4      362.0    Deftones
# 5      362.0    Deftones
# 6      362.0    Deftones
# 7      362.0    Deftones
# 8      362.0    Deftones
# 9      362.0    Deftones

# %%
all_data_df[all_data_df['user_id']=='23553']
# Out:
#        user_id  item_id  org_id freebase_id                 track_name  \
# 616264   23553     7345  181605    m.0lgbq3            Rain When I Die
# 616265   23553     2814  129341    m.0y55z_             Down in a Hole
# 616266   23553     8349  181604    m.0lgbqb                    Sickman
# 616267   23553     8347  181600    m.0lgbqs                   Junkhead
# 616268   23553    13325   18156   m.015vjsc      Into the Rainbow Vein
# 616269   23553    13326   18155   m.015vjsl        Chromakey Dreamcoat
# 616270   23553    13327   18154   m.015vjst    Satellite Anthem Icarus
# 616271   23553    13328   18153   m.0152yhm               Peacock Tail
# 616272   23553    13329   18152   m.0152yhv              Dayvan Cowboy
# 616273   23553    13330   18151   m.015vjtg        A Moment of Clarity
# 616274   23553    13331   18149   m.015vjtx               Sherbet Head
# 616275   23553    13332   18074   m.0152yjq  Oscar See Through Red Eye
# 616276   23553    13333   17986   m.015vjvb              Ataronchronon
# 616277   23553    13334   17985   m.015vjvk           Hey Saturday Sun
# 616278   23553    13335   17984   m.0152ykc     Constants Are Changing
# 616279   23553    13336   17983   m.015vjv_        Slow This Bird Down
# 616280   23553    27386  383782    m.0l17td          Dig Your Own Hole
# 616281   23553    21515  383781    m.0l17tm                Elektrobank
# 616282   23553    32367  383780    m.0l17tv                       Piku
# 616283   23553    18546  318803   m.0f521wz          It Doesn't Matter
# 616284   23553       32  328346    m.0lk4xk                  Rhinosaur
# 616285   23553       33  328345    m.0lk4xs                Zero Chance
# 616286   23553       34  326812    m.0zns0v                    Ty Cobb
#
#         artist_id            artist_name
# 616264       93.0        Alice in Chains
# 616265       93.0        Alice in Chains
# 616266       93.0        Alice in Chains
# 616267       93.0        Alice in Chains
# 616268     2267.0       Boards of Canada
# 616269     2267.0       Boards of Canada
# 616270     2267.0       Boards of Canada
# 616271     2267.0       Boards of Canada
# 616272     2267.0       Boards of Canada
# 616273     2267.0       Boards of Canada
# 616274     2267.0       Boards of Canada
# 616275     2267.0       Boards of Canada
# 616276     2267.0       Boards of Canada
# 616277     2267.0       Boards of Canada
# 616278     2267.0       Boards of Canada
# 616279     2267.0       Boards of Canada
# 616280     3153.0  The Chemical Brothers
# 616281     3153.0  The Chemical Brothers
# 616282     3153.0  The Chemical Brothers
# 616283     3153.0  The Chemical Brothers
# 616284      507.0            Soundgarden
# 616285      507.0            Soundgarden
# 616286      507.0            Soundgarden

# %%
# 欠損値の確認
all_data_df[all_data_df.isnull().any(axis=1)]
# Out:
#        user_id  item_id    org_id freebase_id track_name  artist_id  \
# 23978      211     9107   1087251   m.0113cxd        NaN        NaN
# 26755      240    22624  25143736  m.010y5t16        NaN        NaN
# 27101      246    19115    472926    m.0ncwk7        NaN        NaN
# 29961      282    17554   1087655    m.0sxk4q        NaN        NaN
# 36628      387    17554   1087655    m.0sxk4q        NaN        NaN
# 41737      453    12058   1831823    m.0w0ybh        NaN        NaN
# 42021      460     1383    420269    m.0md727        NaN        NaN
# 44559      496    29863   1087343    m.0zl_f4        NaN        NaN
# 44563      496    46196   2199211   m.0160qst        NaN        NaN
# 46652      532    32460    923499    m.0vwc72        NaN        NaN
# 48712      582    31388   1087634    m.0m6ftn        NaN        NaN
# 54328      654    32510   1831775    m.0t489d        NaN        NaN
# 55290      669    37563   1371140    m.0w341p        NaN        NaN
# 56946      708    30562    795266   m.01233bv        NaN        NaN
# 68107      891    33097    923710   m.01f01t3        NaN        NaN
# 68108      891    30720    923706   m.01f01tb        NaN        NaN
# 69248      916    37160   1366883    m.0sx18k        NaN        NaN
# 70732      947     1383    420269    m.0md727        NaN        NaN
# 72811      979    38721    473040    m.0p_yw1        NaN        NaN
# 72812      979    42256    473039    m.0p_yw8        NaN        NaN
# 72813      979    42257    473037    m.0p_ywq        NaN        NaN
# 72814      979    11270    473036    m.0p_ywy        NaN        NaN
# 72815      979    42258    473035    m.0p_yx4        NaN        NaN
# 72816      979    42259    473021    m.0p_yxt        NaN        NaN
# 72817      979    42260    472993    m.0p_yy0        NaN        NaN
# 73201      984    36224   1351066   m.0dvt2wd        NaN        NaN
# 76588     1040    39620   1087444    m.0lp8hr        NaN        NaN
# 77804     1074    13769   1366873    m.0vg1jk        NaN        NaN
# 78881     1089    39620   1087444    m.0lp8hr        NaN        NaN
# 80198     1129    37563   1371140    m.0w341p        NaN        NaN
# ...        ...      ...       ...         ...        ...        ...
# 564367   19243    33097    923710   m.01f01t3        NaN        NaN
# 565468   19323    17554   1087655    m.0sxk4q        NaN        NaN
# 566410   19389    34237  24983123  m.010dkwgy        NaN        NaN
# 567068   19459    34237  24983123  m.010dkwgy        NaN        NaN
# 568830   19589    42258    473035    m.0p_yx4        NaN        NaN
# 570209   19671    19115    472926    m.0ncwk7        NaN        NaN
# 571562   19786    14817   1087610   m.0fydvl4        NaN        NaN
# 571626   19791    19115    472926    m.0ncwk7        NaN        NaN
# 574625   20024    23010    472921   m.01d6sxg        NaN        NaN
# 577128   20218    17554   1087655    m.0sxk4q        NaN        NaN
# 587679   21066    34237  24983123  m.010dkwgy        NaN        NaN
# 589355   21219    41804    420264   m.016lzf8        NaN        NaN
# 589380   21219    46761    420206   m.0fqypjm        NaN        NaN
# 589855   21257    34237  24983123  m.010dkwgy        NaN        NaN
# 591853   21456    36224   1351066   m.0dvt2wd        NaN        NaN
# 591855   21456    43432   1351060   m.0f87c1r        NaN        NaN
# 592400   21490    34237  24983123  m.010dkwgy        NaN        NaN
# 592882   21545    33097    923710   m.01f01t3        NaN        NaN
# 592883   21545    30720    923706   m.01f01tb        NaN        NaN
# 594260   21669    34237  24983123  m.010dkwgy        NaN        NaN
# 598471   22032    33097    923710   m.01f01t3        NaN        NaN
# 598780   22075    33097    923710   m.01f01t3        NaN        NaN
# 602994   22406    42259    473021    m.0p_yxt        NaN        NaN
# 603074   22406    46761    420206   m.0fqypjm        NaN        NaN
# 604811   22539    34237  24983123  m.010dkwgy        NaN        NaN
# 605696   22620    43432   1351060   m.0f87c1r        NaN        NaN
# 608512   22822    33176    795261   m.0d_rzfk        NaN        NaN
# 608998   22870    39731    472966    m.0pdsvp        NaN        NaN
# 612062   23100    22624  25143736  m.010y5t16        NaN        NaN
# 613014   23198    22624  25143736  m.010y5t16        NaN        NaN
#
#        artist_name
# 23978          NaN
# 26755          NaN
# 27101          NaN
# 29961          NaN
# 36628          NaN
# 41737          NaN
# 42021          NaN
# 44559          NaN
# 44563          NaN
# 46652          NaN
# 48712          NaN
# 54328          NaN
# 55290          NaN
# 56946          NaN
# 68107          NaN
# 68108          NaN
# 69248          NaN
# 70732          NaN
# 72811          NaN
# 72812          NaN
# 72813          NaN
# 72814          NaN
# 72815          NaN
# 72816          NaN
# 72817          NaN
# 73201          NaN
# 76588          NaN
# 77804          NaN
# 78881          NaN
# 80198          NaN
# ...            ...
# 564367         NaN
# 565468         NaN
# 566410         NaN
# 567068         NaN
# 568830         NaN
# 570209         NaN
# 571562         NaN
# 571626         NaN
# 574625         NaN
# 577128         NaN
# 587679         NaN
# 589355         NaN
# 589380         NaN
# 589855         NaN
# 591853         NaN
# 591855         NaN
# 592400         NaN
# 592882         NaN
# 592883         NaN
# 594260         NaN
# 598471         NaN
# 598780         NaN
# 602994         NaN
# 603074         NaN
# 604811         NaN
# 605696         NaN
# 608512         NaN
# 608998         NaN
# 612062         NaN
# 613014         NaN
#
# [246 rows x 7 columns]

# %% [markdown]
# #### data を csvで保存

# %%
master_table_path = './master_table/'

if not os.path.exists(master_table_path):
    os.makedirs(master_table_path)

# %%
all_data_df.to_csv(master_table_path + '{}_interaction_data.csv'.format(target))
